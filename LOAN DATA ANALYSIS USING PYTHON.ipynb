# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# # READING CSV FILE

# %%
loan_csv=pd.read_csv('loan_data.csv')
loan_csv
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 0                 1  debt_consolidation    0.1189       829.10
# 1                 1         credit_card    0.1071       228.22
# 2                 1  debt_consolidation    0.1357       366.86
# 3                 1  debt_consolidation    0.1008       162.34
# 4                 1         credit_card    0.1426       102.92
# ...             ...                 ...       ...          ...
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 0          11.350407  19.48   737        5639.958333      28854        52.1
# ...

# %% [markdown]
# # BASIC FUNCTIONS

# %%
loan_csv.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
loan_csv.tail()
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 9573       12.180755  10.39   672       10474.000000     215372        82.1
# 9574       11.141862   0.21   722        4380.000000        184         1.1
# 9575       10.596635  13.09   687        3450.041667      10036        82.9
# 9576       10.819778  19.18   692        1800.000000          0         3.2
# 9577       11.264464  16.28   732        4740.000000      37879        57.0
#
#       inq.last.6mths  delinq.2yrs  pub.rec  not.fully.paid
# 9573               2            0        0               1
# ...

# %%
loan_csv.shape
# Out:
# (9578, 14)

# %%
loan_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
loan_csv.columns
# Out:
# Index(['credit.policy', 'purpose', 'int.rate', 'installment', 'log.annual.inc',
#        'dti', 'fico', 'days.with.cr.line', 'revol.bal', 'revol.util',
#        'inq.last.6mths', 'delinq.2yrs', 'pub.rec', 'not.fully.paid'],
#       dtype='object')

# %% [markdown]
# # STATISTICAL SUMMARY

# %%
loan_csv.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %%
loan_csv.isnull().sum()
# Out:
# credit.policy        0
# purpose              0
# int.rate             0
# installment          0
# log.annual.inc       0
# dti                  0
# fico                 0
# days.with.cr.line    0
# revol.bal            0
# revol.util           0
# inq.last.6mths       0
# delinq.2yrs          0
# pub.rec              0
# not.fully.paid       0
# dtype: int64

# %% [markdown]
# # CONDITIONAL FILTERING

# %%
loan_csv.head(4)
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
#
#    delinq.2yrs  pub.rec  not.fully.paid
# 0            0        0               0
# 1            0        0               0
# 2            0        0               0
# 3            0        0               0

# %%
loan_csv[(loan_csv['credit.policy']==1) & (loan_csv['purpose']=='credit_card')]
# Out:
#       credit.policy      purpose  int.rate  installment  log.annual.inc  \
# 1                 1  credit_card    0.1071       228.22       11.082143
# 4                 1  credit_card    0.1426       102.92       11.299732
# 5                 1  credit_card    0.0788       125.13       11.904968
# 17                1  credit_card    0.0894       476.58       11.608236
# 22                1  credit_card    0.1355       339.60       11.512925
# ...             ...          ...       ...          ...             ...
# 7663              1  credit_card    0.1273       169.51       10.819778
# 7664              1  credit_card    0.1062       814.00       11.980426
# 7665              1  credit_card    0.0714       170.17       10.757903
# 7675              1  credit_card    0.1385       218.27       10.691945
# 7697              1  credit_card    0.1385       341.04       11.849398
#
#         dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# ...

# %%
loan_csv[(loan_csv['installment']==814.00)]
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 7147              1  debt_consolidation    0.1062        814.0
# 7291              1         credit_card    0.1062        814.0
# 7664              1         credit_card    0.1062        814.0
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 7147       11.918391   3.45   792        8250.041667      42863         0.0
# 7291       11.264464  12.32   757        6450.041667      24413        44.7
# 7664       11.980426  15.20   762        5820.000000      50110        10.5
#
#       inq.last.6mths  delinq.2yrs  pub.rec  not.fully.paid
# 7147               1            0        0               0
# 7291               0            0        0               0
# 7664               2            0        0               0

# %%
loan_csv[loan_csv['installment']==339.60]
# Out:
#      credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 22               1         credit_card    0.1355        339.6       11.512925
# 588              1      small_business    0.1355        339.6       11.178850
# 888              1  debt_consolidation    0.1355        339.6       11.904968
#
#        dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 22    7.94   662        1939.958333      21162        57.7               0
# 588   3.35   662        5460.000000       5261        73.1               2
# 888  10.14   662        4620.000000       3608        37.6               1
#
#      delinq.2yrs  pub.rec  not.fully.paid
# 22             0        0               0
# 588            1        0               1
# 888            1        0               0

# %%
loan_csv[(loan_csv['purpose']=='small_business')]
# Out:
#       credit.policy         purpose  int.rate  installment  log.annual.inc  \
# 13                1  small_business    0.0714        92.82       11.512925
# 42                1  small_business    0.0870        94.98       10.126631
# 51                1  small_business    0.1028       323.98       10.217422
# 52                1  small_business    0.1059       813.65       10.778956
# 55                1  small_business    0.1059       398.69       11.002100
# ...             ...             ...       ...          ...             ...
# 9496              0  small_business    0.1635       169.58       10.566176
# 9535              0  small_business    0.1496       831.52       12.765688
# 9536              0  small_business    0.1348       542.79       12.611538
# 9539              0  small_business    0.1533       870.71       11.849398
# 9554              0  small_business    0.1533       870.71       11.842229
#
# ...

# %%
loan_csv.groupby('purpose')['installment'].sum()
# Out:
# purpose
# all_other              570949.41
# credit_card            403209.90
# debt_consolidation    1420501.23
# educational             74618.69
# home_improvement       212018.03
# major_purchase         106402.47
# small_business         268538.67
# Name: installment, dtype: float64

# %%
loan_csv.groupby('purpose')['installment'].mean()
# Out:
# purpose
# all_other             244.937542
# credit_card           319.500713
# debt_consolidation    358.984390
# educational           217.547201
# home_improvement      337.071590
# major_purchase        243.483913
# small_business        433.826607
# Name: installment, dtype: float64

# %%
loan_csv.groupby('credit.policy')['log.annual.inc'].max()
# Out:
# credit.policy
# 0    13.458836
# 1    14.528354
# Name: log.annual.inc, dtype: float64

# %%
loan_csv.groupby('credit.policy')['log.annual.inc'].min()
# Out:
# credit.policy
# 0    7.547502
# 1    8.294050
# Name: log.annual.inc, dtype: float64

# %% [markdown]
# # NUMERICAL DATA

# %%
num_loan=loan_csv.select_dtypes(exclude='object')

# %%
num_loan
# Out:
#       credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0                 1    0.1189       829.10       11.350407  19.48   737
# 1                 1    0.1071       228.22       11.082143  14.29   707
# 2                 1    0.1357       366.86       10.373491  11.63   682
# 3                 1    0.1008       162.34       11.350407   8.10   712
# 4                 1    0.1426       102.92       11.299732  14.97   667
# ...             ...       ...          ...             ...    ...   ...
# 9573              0    0.1461       344.76       12.180755  10.39   672
# 9574              0    0.1253       257.70       11.141862   0.21   722
# 9575              0    0.1071        97.81       10.596635  13.09   687
# 9576              0    0.1600       351.58       10.819778  19.18   692
# 9577              0    0.1392       853.43       11.264464  16.28   732
#
#       days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# ...

# %% [markdown]
# # CATEGORICAL DATA

# %%
cate_loan=loan_csv.select_dtypes(include='object')

# %%
cate_loan
# Out:
#                  purpose
# 0     debt_consolidation
# 1            credit_card
# 2     debt_consolidation
# 3     debt_consolidation
# 4            credit_card
# ...                  ...
# 9573           all_other
# 9574           all_other
# 9575  debt_consolidation
# 9576    home_improvement
# 9577  debt_consolidation
#
# [9578 rows x 1 columns]

# %% [markdown]
# # STANDARD DEVIATION OF NUMERICAL DATA

# %%
num_loan.std()
# Out:
# credit.policy            0.396245
# int.rate                 0.026847
# installment            207.071301
# log.annual.inc           0.614813
# dti                      6.883970
# fico                    37.970537
# days.with.cr.line     2496.930377
# revol.bal            33756.189557
# revol.util              29.014417
# inq.last.6mths           2.200245
# delinq.2yrs              0.546215
# pub.rec                  0.262126
# not.fully.paid           0.366676
# dtype: float64

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
num_loan['days.with.cr.line'].mean()
# Out:
# 4560.767196529213

# %%
num_loan['days.with.cr.line'].max()
# Out:
# 17639.95833

# %%
num_loan['days.with.cr.line'].mode()[0]
# Out:
# 3660.0

# %%
num_loan['days.with.cr.line'].min()
# Out:
# 178.9583333

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
sb.boxplot(data=num_loan,x='credit.policy',y='installment')
plt.show()

# %%
sb.barplot(data=num_loan,x='credit.policy',y='fico',hue='not.fully.paid')
# Out:
# <Axes: xlabel='credit.policy', ylabel='fico'>
