# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df_csv=pd.read_csv('output.csv')
df_csv
# Out:
#       Feature1  Feature2  Feature3 Feature4  Feature5  Feature6  Feature7  \
# 0         44.0  0.797417 -0.958091      NaN       NaN     158.0  1.490148
# 1         47.0  0.026838 -0.244178        D       NaN       NaN  2.151535
# 2         64.0  0.199990 -1.014799        B       0.0     474.0  1.410613
# 3         67.0  0.474124  0.448040        B       NaN     166.0  0.635091
# 4          NaN  0.598516  0.087839      NaN       0.0       NaN  0.392104
# ...        ...       ...       ...      ...       ...       ...       ...
# 4995       NaN  0.819440  0.415931        C       0.0       NaN  1.765590
# 4996       NaN  0.032140 -1.445420        C       1.0       NaN  0.806246
# 4997      92.0  0.263300  0.986722        C       NaN      78.0  1.326853
# 4998      91.0  0.640986 -1.199847        A       0.0      51.0  0.312256
# 4999       NaN  0.901570  1.836382      NaN       0.0       NaN  2.087461
#
#       Feature8  Feature9  Feature10  Feature11 Feature12  Feature13  \
# ...

# %%
df_csv.head()
# Out:
#    Feature1  Feature2  Feature3 Feature4  Feature5  Feature6  Feature7  \
# 0      44.0  0.797417 -0.958091      NaN       NaN     158.0  1.490148
# 1      47.0  0.026838 -0.244178        D       NaN       NaN  2.151535
# 2      64.0  0.199990 -1.014799        B       0.0     474.0  1.410613
# 3      67.0  0.474124  0.448040        B       NaN     166.0  0.635091
# 4       NaN  0.598516  0.087839      NaN       0.0       NaN  0.392104
#
#    Feature8  Feature9  Feature10  Feature11 Feature12  Feature13  Feature14  \
# 0  5.166124  2.277942        NaN          5         X          1  Category1
# 1  0.450312 -3.395356        NaN          3         X          0  Category1
# 2  6.786555 -3.070746        NaN          7         Z          0  Category1
# 3  1.937158 -0.246269   6.004975         20         X          0  Category1
# 4  4.010937  3.215086   2.891199          3         Z          0  Category1
#
#   Feature15  Feature16  Feature17 Feature18 Feature19 Feature20
# ...

# %%
df_csv.tail()
# Out:
#       Feature1  Feature2  Feature3 Feature4  Feature5  Feature6  Feature7  \
# 4995       NaN  0.819440  0.415931        C       0.0       NaN  1.765590
# 4996       NaN  0.032140 -1.445420        C       1.0       NaN  0.806246
# 4997      92.0  0.263300  0.986722        C       NaN      78.0  1.326853
# 4998      91.0  0.640986 -1.199847        A       0.0      51.0  0.312256
# 4999       NaN  0.901570  1.836382      NaN       0.0       NaN  2.087461
#
#       Feature8  Feature9  Feature10  Feature11 Feature12  Feature13  \
# 4995  1.929735 -1.951884        NaN          1         Z          1
# 4996  8.765315 -1.866815        NaN          1         Y          0
# 4997  4.489722  1.720671   6.877962          1         X          0
# 4998  2.773963 -3.320704   6.138322          2         X          0
# 4999  6.854886 -0.259228   6.068139          6         X          0
#
#       Feature14 Feature15  Feature16  Feature17 Feature18 Feature19  \
# ...

# %%
df_csv.shape
# Out:
# (5000, 20)

# %%
df_csv.columns
# Out:
# Index(['Feature1', 'Feature2', 'Feature3', 'Feature4', 'Feature5', 'Feature6',
#        'Feature7', 'Feature8', 'Feature9', 'Feature10', 'Feature11',
#        'Feature12', 'Feature13', 'Feature14', 'Feature15', 'Feature16',
#        'Feature17', 'Feature18', 'Feature19', 'Feature20'],
#       dtype='object')

# %%
df_csv.iloc[[1,3,5,7]]
# Out:
#    Feature1  Feature2  Feature3 Feature4  Feature5    Feature6  Feature7  \
# 1      47.0  0.026838 -0.244178        D       NaN         NaN  2.151535
# 3      67.0  0.474124  0.448040        B       NaN  166.000000  0.635091
# 5       NaN  0.879753 -0.147499        D       NaN  -40.591272  0.763004
# 7       NaN  0.522327  0.126673      NaN       1.0  840.000000  3.156345
#
#    Feature8  Feature9  Feature10  Feature11 Feature12  Feature13  Feature14  \
# 1  0.450312 -3.395356        NaN          3         X          0  Category1
# 3  1.937158 -0.246269   6.004975         20         X          0  Category1
# 5  3.846180 -4.028924        NaN          2         Y          0  Category1
# 7  5.719082 -1.149391   8.114887          3         X          0  Category1
#
#   Feature15  Feature16  Feature17 Feature18 Feature19 Feature20
# 1   Option2        NaN  13.355832       Yes       Low       cat
# 3   Option2        NaN   7.687652       Yes       Low       cat
# ...

# %%
df_csv.loc[[2,0]]
# Out:
#    Feature1  Feature2  Feature3 Feature4  Feature5  Feature6  Feature7  \
# 2      64.0  0.199990 -1.014799        B       0.0     474.0  1.410613
# 0      44.0  0.797417 -0.958091      NaN       NaN     158.0  1.490148
#
#    Feature8  Feature9  Feature10  Feature11 Feature12  Feature13  Feature14  \
# 2  6.786555 -3.070746        NaN          7         Z          0  Category1
# 0  5.166124  2.277942        NaN          5         X          1  Category1
#
#   Feature15  Feature16  Feature17 Feature18 Feature19 Feature20
# 2   Option2        NaN  13.449484       Yes    Medium       dog
# 0   Option4   8.824345  11.711130       Yes       Low       NaN

# %%
df_csv.describe()
# Out:
#           Feature1     Feature2     Feature3     Feature5     Feature6  \
# count  2296.000000  5000.000000  5000.000000  2968.000000  3016.000000
# mean     48.102787     0.509843    -0.009058     0.103774   506.703346
# std      28.605603     0.322480     1.010739     0.305018   351.183479
# min       0.000000    -0.476438    -3.644316     0.000000  -538.762910
# 25%      24.000000     0.253741    -0.686737     0.000000   220.000000
# 50%      47.000000     0.513507    -0.017156     0.000000   507.679700
# 75%      72.000000     0.770195     0.688604     0.000000   784.000000
# max      99.000000     1.497998     3.422062     1.000000  1543.622087
#
#           Feature7     Feature8     Feature9    Feature10    Feature11  \
# count  5000.000000  4899.000000  5000.000000  2164.000000  5000.000000
# mean      0.993603     3.996315    -0.024540     4.998186     4.967800
# std       0.991321     2.811892     1.829975     2.289341     4.571624
# ...

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Feature1   2296 non-null   float64
#  1   Feature2   5000 non-null   float64
#  2   Feature3   5000 non-null   float64
#  3   Feature4   3132 non-null   object
#  4   Feature5   2968 non-null   float64
#  5   Feature6   3016 non-null   float64
#  6   Feature7   5000 non-null   float64
#  7   Feature8   4899 non-null   float64
#  8   Feature9   5000 non-null   float64
#  9   Feature10  2164 non-null   float64
#  10  Feature11  5000 non-null   int64
#  11  Feature12  5000 non-null   object
#  12  Feature13  5000 non-null   int64
#  13  Feature14  5000 non-null   object
#  14  Feature15  5000 non-null   object
#  15  Feature16  2994 non-null   float64
#  16  Feature17  5000 non-null   float64
#  17  Feature18  5000 non-null   object
#  18  Feature19  4705 non-null   object
# ...

# %%
df_csv.isnull().sum()
# Out:
# Feature1     2704
# Feature2        0
# Feature3        0
# Feature4     1868
# Feature5     2032
# Feature6     1984
# Feature7        0
# Feature8      101
# Feature9        0
# Feature10    2836
# Feature11       0
# Feature12       0
# Feature13       0
# Feature14       0
# Feature15       0
# Feature16    2006
# Feature17       0
# Feature18       0
# Feature19     295
# Feature20    1733
# dtype: int64

# %%
df_csv['Feature1'].ffill(inplace=True)

# %%
df_csv['Feature4'].fillna('B',inplace=True)

# %%
df_csv['Feature5'].mean().round(6)
# Out:
# 0.107443

# %%
df_csv['Feature5'].fillna('mean',inplace=True)

# %%
df_csv['Feature6'].mean().round(6)
# Out:
# 507.379073

# %%
df_csv['Feature6'].fillna('mean',inplace=True)

# %%
df_csv['Feature8'].ffill(inplace=True)

# %%
df_csv['Feature10'].bfill(inplace=True)

# %%
df_csv['Feature16'].mode()[0].round(6)
# Out:
# 3.627312

# %%
df_csv['Feature16'].fillna('mode',inplace=True)

# %%
df_csv['Feature19'].mode()[0]
# Out:
# 'High'

# %%
df_csv['Feature19'].fillna('mode',inplace=True)

# %%
df_csv['Feature20'].mode()[0]
# Out:
# 'cat'

# %%
df_csv['Feature20'].fillna('mode',inplace=True)

# %%
df_csv.isnull().sum()
# Out:
# Feature1     0
# Feature2     0
# Feature3     0
# Feature4     0
# Feature5     0
# Feature6     0
# Feature7     0
# Feature8     0
# Feature9     0
# Feature10    0
# Feature11    0
# Feature12    0
# Feature13    0
# Feature14    0
# Feature15    0
# Feature16    0
# Feature17    0
# Feature18    0
# Feature19    0
# Feature20    0
# dtype: int64

# %%
df_csv['Feature4'].unique()
# Out:
# array(['D', 'B', 'A', 'C', 'mode'], dtype=object)

# %%
df_csv['Feature4']=df_csv['Feature4'].replace('mode','B')

# %%
df_csv['Feature4'].unique()
# Out:
# array(['D', 'B', 'A', 'C'], dtype=object)

# %%
df_csv['Feature5'].unique()
# Out:
# array(['mean', 0.0, 1.0], dtype=object)

# %%
df_csv['Feature5']=df_csv['Feature5'].replace('mean',1.0)

# %%
df_csv['Feature5'].unique()
# Out:
# array([1., 0.])

# %%
df_csv['Feature6'].unique()
# Out:
# array([158.0, 474.0, 166.0, ..., 1305.9595666779217, 1473.1677724249423,
#        'mean'], dtype=object)

# %%
df_csv['Feature6']=df_csv['Feature6'].replace('mean',1400)

# %%
df_csv['Feature6'].unique()
# Out:
# array([ 158.        ,  474.        ,  166.        , ..., 1305.95956668,
#        1473.16777242, 1400.        ])

# %%
df_csv['Feature6'].dtypes
# Out:
# dtype('float64')

# %%
df_csv.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool

# %%
df_csv.drop_duplicates()
# Out:
#       Feature1  Feature2  Feature3 Feature4  Feature5     Feature6  Feature7  \
# 0         44.0  0.797417 -0.958091        D       1.0   158.000000  1.490148
# 1         47.0  0.026838 -0.244178        D       1.0   474.000000  2.151535
# 2         64.0  0.199990 -1.014799        B       0.0   474.000000  1.410613
# 3         67.0  0.474124  0.448040        B       0.0   166.000000  0.635091
# 4         67.0  0.598516  0.087839        D       0.0   -40.591272  0.392104
# ...        ...       ...       ...      ...       ...          ...       ...
# 4995      84.0  0.819440  0.415931        C       0.0    78.000000  1.765590
# 4996      84.0  0.032140 -1.445420        C       1.0    78.000000  0.806246
# 4997      92.0  0.263300  0.986722        C       1.0    78.000000  1.326853
# 4998      91.0  0.640986 -1.199847        A       0.0    51.000000  0.312256
# 4999      91.0  0.901570  1.836382        B       0.0  1400.000000  2.087461
#
# ...

# %%
df_csv['Feature16'].unique()
# Out:
# array([8.824344611530917, 'mode', 11.25937103731184, ...,
#        5.682022151686239, 4.574748376521916, 12.801075326632915],
#       dtype=object)

# %%
df_csv['Feature16']=df_csv['Feature16'].replace('mode','8.786543291')

# %%
df_csv['Feature16'].unique()
# Out:
# array([8.824344611530917, '8.786543291', 11.25937103731184, ...,
#        5.682022151686239, 4.574748376521916, 12.801075326632915],
#       dtype=object)

# %%
df_csv['Feature20']=df_csv['Feature20'].replace('mode','cat')

# %%
df_csv['Feature20'].unique()
# Out:
# array(['cat', 'dog', 'some other'], dtype=object)

# %%
num_csv=df_csv.select_dtypes(exclude=object)

# %%
num_csv
# Out:
#       Feature1  Feature2  Feature3  Feature5     Feature6  Feature7  Feature8  \
# 0         44.0  0.797417 -0.958091       1.0   158.000000  1.490148  5.166124
# 1         47.0  0.026838 -0.244178       1.0   474.000000  2.151535  0.450312
# 2         64.0  0.199990 -1.014799       0.0   474.000000  1.410613  6.786555
# 3         67.0  0.474124  0.448040       0.0   166.000000  0.635091  1.937158
# 4         67.0  0.598516  0.087839       0.0   -40.591272  0.392104  4.010937
# ...        ...       ...       ...       ...          ...       ...       ...
# 4995      84.0  0.819440  0.415931       0.0    78.000000  1.765590  1.929735
# 4996      84.0  0.032140 -1.445420       1.0    78.000000  0.806246  8.765315
# 4997      92.0  0.263300  0.986722       1.0    78.000000  1.326853  4.489722
# 4998      91.0  0.640986 -1.199847       0.0    51.000000  0.312256  2.773963
# 4999      91.0  0.901570  1.836382       0.0  1400.000000  2.087461  6.854886
#
# ...

# %%
cat_csv=df_csv.select_dtypes(include=object)

# %%
cat_csv
# Out:
#      Feature4 Feature12  Feature14 Feature15    Feature16 Feature18 Feature19  \
# 0           D         X  Category1   Option4     8.824345       Yes       Low
# 1           D         X  Category1   Option2  8.786543291       Yes       Low
# 2           B         Z  Category1   Option2  8.786543291       Yes    Medium
# 3           B         X  Category1   Option2  8.786543291       Yes       Low
# 4           D         Z  Category1   Option3    11.259371       Yes       Low
# ...       ...       ...        ...       ...          ...       ...       ...
# 4995        C         Z  Category2   Option4  8.786543291        No       Low
# 4996        C         Y  Category3   Option4     6.368173       Yes    Medium
# 4997        C         X  Category1   Option4     5.682022       Yes    Medium
# 4998        A         X  Category1   Option3     4.574748        No    Medium
# 4999        B         X  Category2   Option2    12.801075       Yes      High
#
#        Feature20
# ...

# %%
num_csv[(num_csv['Feature5']==1.0) & (num_csv['Feature11']>10)]
# Out:
#       Feature1  Feature2  Feature3  Feature5     Feature6  Feature7  \
# 163       30.0  0.364857 -1.301196       1.0   280.000000  0.225611
# 331       73.0  0.272064 -1.614908       1.0   521.000000  1.958589
# 343       51.0  0.724042  0.326311       1.0   110.000000  1.784348
# 344        8.0  0.784353 -0.259223       1.0   913.000000  0.510779
# 373       83.0 -0.349753 -1.333440       1.0   275.501246  0.415291
# 381       13.0  0.643452 -1.997634       1.0   631.000000  1.503094
# 440       66.0  0.726467 -0.109638       1.0   667.000000  0.014297
# 659       69.0  0.417519 -1.031360       1.0   792.000000  0.017826
# 660       77.0  0.547923 -0.668171       1.0   792.000000  0.421740
# 661       77.0  0.717488  0.369220       1.0   729.000000  1.248358
# 947       19.0  0.022376  0.490731       1.0   902.000000  1.313228
# 1040      17.0  0.073445  0.918324       1.0   959.000000  0.809527
# 1337      60.0  0.381837 -2.410214       1.0   490.000000  0.156154
# ...

# %%
num_csv[(num_csv['Feature1']>50) & (num_csv['Feature6']>1000)]
# Out:
#       Feature1  Feature2  Feature3  Feature5     Feature6  Feature7  Feature8  \
# 249       67.0  0.863491 -0.178476       0.0  1141.328907  0.347753  6.483909
# 250       67.0  0.986415 -1.401911       0.0  1141.328907  0.199801  3.293883
# 403       53.0  0.863660  1.153386       0.0  1159.364397  0.951497  3.347802
# 414       59.0  0.441921 -0.193503       0.0  1010.090471  0.181539  2.831410
# 554       83.0  0.624164  0.185461       0.0  1340.366364  0.059275  2.837757
# ...        ...       ...       ...       ...          ...       ...       ...
# 4966      56.0  0.884540 -0.020934       0.0  1214.978226  0.136809  1.047246
# 4978      76.0  0.468066  0.483292       0.0  1305.959567  0.937314  3.336017
# 4981      58.0  0.759597  0.906259       0.0  1473.167772  3.052644  7.492213
# 4982      58.0  1.445728  1.780657       0.0  1473.167772  0.574001  1.426179
# 4999      91.0  0.901570  1.836382       0.0  1400.000000  2.087461  6.854886
#
# ...

# %%
num_csv[(num_csv['Feature2']>1.0)]
# Out:
#       Feature1  Feature2  Feature3  Feature5     Feature6  Feature7  \
# 18        88.0  1.119411  0.899467       0.0   156.505327  0.367481
# 91        78.0  1.353971  0.126109       1.0  -185.152749  0.842072
# 152       54.0  1.388499 -0.368300       0.0   -94.260431  0.342759
# 170       72.0  1.045150 -0.507527       0.0  -493.752865  1.142937
# 185       75.0  1.430571 -0.635757       0.0    51.493518  0.480897
# ...        ...       ...       ...       ...          ...       ...
# 4763      22.0  1.090194 -1.242668       0.0    31.750144  0.891759
# 4899      62.0  1.245958 -1.598708       0.0   776.464111  0.371770
# 4916      22.0  1.411470 -0.413017       0.0    21.686099  0.141383
# 4920      57.0  1.167133 -0.797216       0.0  -219.805997  0.093671
# 4982      58.0  1.445728  1.780657       0.0  1473.167772  0.574001
#
#        Feature8  Feature9  Feature10  Feature11  Feature13  Feature17
# 18     1.984581 -1.886895   6.057295          4          1   8.002058
# ...

# %%
num_csv[(num_csv['Feature8']>=6.0)]
# Out:
#       Feature1  Feature2  Feature3  Feature5     Feature6  Feature7  Feature8  \
# 2         64.0  0.199990 -1.014799       0.0   474.000000  1.410613  6.786555
# 8         36.0  0.907293  0.093092       0.0   821.000000  3.361390  9.777295
# 10        36.0  0.730194 -0.482988       0.0    53.000000  0.977198  9.674929
# 12        88.0  0.329888  0.245180       0.0    80.000000  0.814215  8.156511
# 21        88.0  0.397841  0.248413       0.0   375.494983  0.881802  6.783169
# ...        ...       ...       ...       ...          ...       ...       ...
# 4977      14.0  0.549802 -0.185693       0.0  1305.959567  0.969918  6.768639
# 4981      58.0  0.759597  0.906259       0.0  1473.167772  3.052644  7.492213
# 4986      58.0  0.986450 -0.923236       0.0   783.000000  1.032542  6.613200
# 4996      84.0  0.032140 -1.445420       1.0    78.000000  0.806246  8.765315
# 4999      91.0  0.901570  1.836382       0.0  1400.000000  2.087461  6.854886
#
# ...

# %%
cat_csv[cat_csv['Feature20']=='cat']
# Out:
#      Feature4 Feature12  Feature14 Feature15    Feature16 Feature18 Feature19  \
# 0           D         X  Category1   Option4     8.824345       Yes       Low
# 1           D         X  Category1   Option2  8.786543291       Yes       Low
# 3           B         X  Category1   Option2  8.786543291       Yes       Low
# 4           D         Z  Category1   Option3    11.259371       Yes       Low
# 5           D         Y  Category1   Option3     11.85707       Yes    Medium
# ...       ...       ...        ...       ...          ...       ...       ...
# 4991        D         X  Category1   Option1    13.258573       Yes      High
# 4992        C         Y  Category3   Option2  8.786543291       Yes       Low
# 4995        C         Z  Category2   Option4  8.786543291        No       Low
# 4996        C         Y  Category3   Option4     6.368173       Yes    Medium
# 4997        C         X  Category1   Option4     5.682022       Yes    Medium
#
#      Feature20
# 0          cat
# ...

# %%
cat_csv[(cat_csv['Feature4']=='A')]
# Out:
#      Feature4 Feature12  Feature14 Feature15    Feature16 Feature18 Feature19  \
# 10          A         X  Category1   Option3  8.786543291       Yes       Low
# 11          A         Y  Category1   Option3  8.786543291       Yes    Medium
# 16          A         X  Category1   Option4    12.719932        No    Medium
# 17          A         Z  Category1   Option4     9.249617        No      High
# 18          A         X  Category1   Option4  8.786543291       Yes      High
# ...       ...       ...        ...       ...          ...       ...       ...
# 4964        A         Y  Category1   Option3  8.786543291       Yes       Low
# 4972        A         Y  Category1   Option3    11.978171       Yes      High
# 4986        A         Z  Category1   Option4    11.638553       Yes       Low
# 4987        A         Y  Category1   Option3  8.786543291       Yes    Medium
# 4998        A         X  Category1   Option3     4.574748        No    Medium
#
#        Feature20
# ...

# %%
cat_csv[(cat_csv['Feature12']=='X')]
# Out:
#      Feature4 Feature12  Feature14 Feature15    Feature16 Feature18 Feature19  \
# 0           D         X  Category1   Option4     8.824345       Yes       Low
# 1           D         X  Category1   Option2  8.786543291       Yes       Low
# 3           B         X  Category1   Option2  8.786543291       Yes       Low
# 7           B         X  Category1   Option1    11.946109       Yes       Low
# 8           B         X  Category3   Option3    12.543174       Yes      High
# ...       ...       ...        ...       ...          ...       ...       ...
# 4989        C         X  Category1   Option1     8.178803        No      High
# 4991        D         X  Category1   Option1    13.258573       Yes      High
# 4997        C         X  Category1   Option4     5.682022       Yes    Medium
# 4998        A         X  Category1   Option3     4.574748        No    Medium
# 4999        B         X  Category2   Option2    12.801075       Yes      High
#
#        Feature20
# ...

# %%
cat_csv[(cat_csv['Feature15']=='Option1') & (cat_csv['Feature19']=='High')]
# Out:
#      Feature4 Feature12  Feature14 Feature15    Feature16 Feature18 Feature19  \
# 21          D         Y  Category2   Option1     9.121466        No      High
# 23          D         Y  Category1   Option1  8.786543291       Yes      High
# 27          C         Y  Category1   Option1  8.786543291       Yes      High
# 33          A         X  Category1   Option1    11.305325        No      High
# 48          D         Y  Category2   Option1     9.662369        No      High
# ...       ...       ...        ...       ...          ...       ...       ...
# 4932        C         Y  Category2   Option1  8.786543291       Yes      High
# 4939        D         X  Category3   Option1    10.695246        No      High
# 4949        A         Y  Category1   Option1  8.786543291       Yes      High
# 4989        C         X  Category1   Option1     8.178803        No      High
# 4991        D         X  Category1   Option1    13.258573       Yes      High
#
#      Feature20
# 21         cat
# ...

# %%
sb.countplot(data=cat_csv,x='Feature4')
# Out:
# <Axes: xlabel='Feature4', ylabel='count'>

# %%
num_csv['Feature1'].sort_values(ascending=False)
# Out:
# 3034    99.0
# 1807    99.0
# 1472    99.0
# 4590    99.0
# 4589    99.0
#         ...
# 2847     0.0
# 2536     0.0
# 2846     0.0
# 108      0.0
# 79       0.0
# Name: Feature1, Length: 5000, dtype: float64

# %%
num_csv['Feature2'].sort_values(ascending=True)
# Out:
# 2322   -0.476438
# 1752   -0.473904
# 2293   -0.473034
# 2141   -0.468986
# 1122   -0.468434
#           ...
# 2417    1.484813
# 3614    1.490420
# 4305    1.493779
# 3805    1.493799
# 3031    1.497998
# Name: Feature2, Length: 5000, dtype: float64

# %%
num_csv['Feature5'].value_counts(ascending=True)
# Out:
# 1.0     539
# 0.0    4461
# Name: Feature5, dtype: int64
