# %%
import numpy as np
import pandas as pd

# %%
# READING CSV FILE
mobile_df=pd.read_csv('smartphones.csv')
mobile_df
# Out:
#      Unnamed: 0 brand_name                                      model   price  \
# 0             0      apple                            Apple iPhone 11   38999
# 1             1      apple                    Apple iPhone 11 (128GB)   46999
# 2             2      apple                    Apple iPhone 11 Pro Max  109900
# 3             3      apple                            Apple iPhone 12   51999
# 4             4      apple                    Apple iPhone 12 (128GB)   55999
# ..          ...        ...                                        ...     ...
# 975         975     xiaomi                    Xiaomi Redmi Note 9 Pro   13999
# 976         976     xiaomi  Xiaomi Redmi Note 9 Pro (4GB RAM + 128GB)   14439
# 977         977     xiaomi                Xiaomi Redmi Note 9 Pro Max   16490
# 978         978        zte                               ZTE Axon 30S   19999
# 979         979        zte                       ZTE Axon 40 Ultra 5G   61990
#
# ...

# %%
# DROPPING UNNECESSARY COLUMN
mobile_df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
mobile_df
# Out:
#     brand_name                                      model   price  avg_rating  \
# 0        apple                            Apple iPhone 11   38999         7.3
# 1        apple                    Apple iPhone 11 (128GB)   46999         7.5
# 2        apple                    Apple iPhone 11 Pro Max  109900         7.7
# 3        apple                            Apple iPhone 12   51999         7.4
# 4        apple                    Apple iPhone 12 (128GB)   55999         7.5
# ..         ...                                        ...     ...         ...
# 975     xiaomi                    Xiaomi Redmi Note 9 Pro   13999         7.5
# 976     xiaomi  Xiaomi Redmi Note 9 Pro (4GB RAM + 128GB)   14439         7.7
# 977     xiaomi                Xiaomi Redmi Note 9 Pro Max   16490         8.0
# 978        zte                               ZTE Axon 30S   19999         8.2
# 979        zte                       ZTE Axon 40 Ultra 5G   61990         8.9
#
# ...

# %%
# FETCHING FIRST 5 ROWS
mobile_df.head()
# Out:
#   brand_name                    model   price  avg_rating  5G_or_not  \
# 0      apple          Apple iPhone 11   38999         7.3          0
# 1      apple  Apple iPhone 11 (128GB)   46999         7.5          0
# 2      apple  Apple iPhone 11 Pro Max  109900         7.7          0
# 3      apple          Apple iPhone 12   51999         7.4          1
# 4      apple  Apple iPhone 12 (128GB)   55999         7.5          1
#
#   processor_brand  num_cores  processor_speed  battery_capacity  \
# 0          bionic        6.0             2.65            3110.0
# 1          bionic        6.0             2.65            3110.0
# 2          bionic        6.0             2.65            3500.0
# 3          bionic        6.0             3.10            4500.0
# 4          bionic        6.0             3.10            4500.0
#
#    fast_charging_available  ...  internal_memory  screen_size  refresh_rate  \
# 0                        0  ...               64          6.1            60
# ...

# %%
# FETCHING LAST 5 ROWS
mobile_df.tail()
# Out:
#     brand_name                                      model  price  avg_rating  \
# 975     xiaomi                    Xiaomi Redmi Note 9 Pro  13999         7.5
# 976     xiaomi  Xiaomi Redmi Note 9 Pro (4GB RAM + 128GB)  14439         7.7
# 977     xiaomi                Xiaomi Redmi Note 9 Pro Max  16490         8.0
# 978        zte                               ZTE Axon 30S  19999         8.2
# 979        zte                       ZTE Axon 40 Ultra 5G  61990         8.9
#
#      5G_or_not processor_brand  num_cores  processor_speed  battery_capacity  \
# 975          0      snapdragon        8.0              2.3            5020.0
# 976          0      snapdragon        8.0              2.3            5020.0
# 977          0      snapdragon        8.0              2.3            5020.0
# 978          1      snapdragon        8.0              3.2            4200.0
# 979          1      snapdragon        8.0              3.0            5000.0
#
# ...

# %%
# FETCHING SHAPE OF DATASET
mobile_df.shape
# Out:
# (980, 22)

# %%
# FETCHING NO.OF COLUMNS
mobile_df.columns
# Out:
# Index(['brand_name', 'model', 'price', 'avg_rating', '5G_or_not',
#        'processor_brand', 'num_cores', 'processor_speed', 'battery_capacity',
#        'fast_charging_available', 'fast_charging', 'ram_capacity',
#        'internal_memory', 'screen_size', 'refresh_rate', 'num_rear_cameras',
#        'os', 'primary_camera_rear', 'primary_camera_front',
#        'extended_memory_available', 'resolution_height', 'resolution_width'],
#       dtype='object')

# %%
# INFORMATION ABOUT DATASET
mobile_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int64
#  3   avg_rating                 980 non-null    float64
#  4   5G_or_not                  980 non-null    int64
#  5   processor_brand            980 non-null    object
#  6   num_cores                  980 non-null    float64
#  7   processor_speed            980 non-null    float64
#  8   battery_capacity           980 non-null    float64
#  9   fast_charging_available    980 non-null    int64
#  10  fast_charging              980 non-null    float64
#  11  ram_capacity               980 non-null    int64
#  12  internal_memory            980 non-null    int64
# ...

# %%
# STATISTICAL SUMMARY OF DATASET
mobile_df.describe()
# Out:
#                price  avg_rating   5G_or_not   num_cores  processor_speed  \
# count     980.000000  980.000000  980.000000  980.000000       980.000000
# mean    32520.504082    7.843776    0.560204    7.773469         2.440592
# std     39531.812669    0.703059    0.496616    0.834466         0.468436
# min      3499.000000    6.000000    0.000000    4.000000         1.200000
# 25%     12999.000000    7.500000    0.000000    8.000000         2.050000
# 50%     19994.500000    8.000000    1.000000    8.000000         2.360000
# 75%     35491.500000    8.400000    1.000000    8.000000         2.850000
# max    650000.000000    8.900000    1.000000    8.000000         3.220000
#
#        battery_capacity  fast_charging_available  fast_charging  ram_capacity  \
# count        980.000000               980.000000     980.000000    980.000000
# mean        4814.181633                 0.854082      41.562245      6.560204
# ...

# %%
#FINDING THE NULL VALUES
mobile_df.isnull().sum()
# Out:
# brand_name                   0
# model                        0
# price                        0
# avg_rating                   0
# 5G_or_not                    0
# processor_brand              0
# num_cores                    0
# processor_speed              0
# battery_capacity             0
# fast_charging_available      0
# fast_charging                0
# ram_capacity                 0
# internal_memory              0
# screen_size                  0
# refresh_rate                 0
# num_rear_cameras             0
# os                           0
# primary_camera_rear          0
# primary_camera_front         0
# extended_memory_available    0
# resolution_height            0
# resolution_width             0
# dtype: int64

# %%
# FINDING DUPLICATE ROWS
mobile_df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 975    False
# 976    False
# 977    False
# 978    False
# 979    False
# Length: 980, dtype: bool

# %%
# REMOVING DUPLICATED ROWS
mobile_df.drop_duplicates()
# Out:
#     brand_name                                      model   price  avg_rating  \
# 0        apple                            Apple iPhone 11   38999         7.3
# 1        apple                    Apple iPhone 11 (128GB)   46999         7.5
# 2        apple                    Apple iPhone 11 Pro Max  109900         7.7
# 3        apple                            Apple iPhone 12   51999         7.4
# 4        apple                    Apple iPhone 12 (128GB)   55999         7.5
# ..         ...                                        ...     ...         ...
# 975     xiaomi                    Xiaomi Redmi Note 9 Pro   13999         7.5
# 976     xiaomi  Xiaomi Redmi Note 9 Pro (4GB RAM + 128GB)   14439         7.7
# 977     xiaomi                Xiaomi Redmi Note 9 Pro Max   16490         8.0
# 978        zte                               ZTE Axon 30S   19999         8.2
# 979        zte                       ZTE Axon 40 Ultra 5G   61990         8.9
#
# ...

# %%
mobile_df['price'].unique()
# Out:
# array([ 38999,  46999, 109900,  51999,  55999,  67999,  40999,  45999,
#        119900, 139900,  62999,  72999,  91999,  64900, 147900, 129900,
#        179900,  65999,  75999,  95999,  69990,  74999,  84999, 104999,
#        119990, 172999, 129990, 182999, 139990, 169900,  82990,  84990,
#        130990, 142990, 149900,  52990,  29990,  39900,  43900,  49990,
#         71999,  39999,  89999, 107990,  75990,  63990,   8990,  14990,
#         14999,   9990,   6190,   6999,   7499,  15990,  15999,  20120,
#         36000,  32999,  40480,  54300,  79700,  29999,  53100,  81999,
#         34990,  53990,  70990,  32990,  24990,  39990,  30990,  54990,
#         94990,   9999,  13999,  16999,  27999,  10949, 214990,  99990,
#        239999, 169000, 162990,  23999,  21990,  19990,  22990,  60999,
#          6799,   7999,   8099,   9690,   8910,  10850,  12340,  17999,
#         19999,   8999,  12999,  12799,  11700,  16900,  18999,   7320,
# ...

# %%
mobile_df['price'].sort_values(ascending=True)
# Out:
# 497      3499
# 199      3890
# 198      3990
# 170      3999
# 183      4499
#         ...
# 873    199990
# 91     214990
# 94     239999
# 909    480000
# 732    650000
# Name: price, Length: 980, dtype: int64

# %%
mobile_df['battery_capacity'].sort_values(ascending=True)
# Out:
# 42      1821.0
# 821     1900.0
# 55      2000.0
# 41      2050.0
# 59      2150.0
#         ...
# 712     7000.0
# 411     8000.0
# 410     9800.0
# 409    21000.0
# 58     22000.0
# Name: battery_capacity, Length: 980, dtype: float64

# %%
mobile_df['model'].value_counts(ascending=False)
# Out:
# Apple iPhone SE 2020             1
# OPPO A54                         1
# OPPO A54 (6GB RAM + 128GB)       1
# OPPO A55 4G                      1
# OPPO A55 4G (6GB RAM + 128GB)    1
#                                 ..
# Vivo X80 Pro 5G                  1
# Oppo Find X6 Pro                 1
# Oppo Find X6                     1
# Apple iPhone 15 Ultra            1
# Doogee V Max                     1
# Name: model, Length: 980, dtype: int64

# %% [markdown]
# # PERFORMING EDA

# %%
# NUMERICAL DATA
num_df=mobile_df.select_dtypes(exclude=object)

# %%
num_df
# Out:
#      price  avg_rating  5G_or_not  num_cores  processor_speed  \
# 42   39900         6.3          0        6.0             2.65
# 821   7499         8.0          0        4.0             1.30
# 55   14999         8.0          0        4.0             1.30
# 41   29990         6.1          0        6.0             2.65
# 59    9990         8.0          0        8.0             2.00
# ..     ...         ...        ...        ...              ...
# 712   9999         7.4          0        8.0             2.00
# 411  25899         7.2          0        8.0             2.00
# 410  22990         8.2          0        8.0             2.20
# 409  29990         8.4          0        8.0             2.00
# 58   45999         8.8          1        8.0             2.60
#
#      battery_capacity  fast_charging_available  fast_charging  ram_capacity  \
# 42             1821.0                        1           18.0             3
# ...

# %%
# CATEGORICAL DATA
cat_df=mobile_df.select_dtypes(include=object)

# %%
cat_df
# Out:
#     brand_name                 model processor_brand       os
# 42       apple  Apple iPhone SE 2020          bionic      ios
# 821       vivo              Vivo Y25           helio  android
# 55         cat          CAT S22 Flip      snapdragon  android
# 41       apple        Apple iPhone 9          bionic      ios
# 59      duoqin        Duoqin F22 Pro           helio  android
# ..         ...                   ...             ...      ...
# 712      tecno          Tecno Pova 3           helio  android
# 411    oukitel           Oukitel WP9           helio  android
# 410    oukitel          Oukitel WP21           helio  android
# 409    oukitel          Oukitel WP19           helio  android
# 58      doogee          Doogee V Max       dimensity  android
#
# [980 rows x 4 columns]

# %%
# UNIVARIATE ANALYSIS
mobile_df[(mobile_df['avg_rating']>7)]
# Out:
#     brand_name            model  price  avg_rating  5G_or_not processor_brand  \
# 821       vivo         Vivo Y25   7499         8.0          0           helio
# 55         cat     CAT S22 Flip  14999         8.0          0      snapdragon
# 59      duoqin   Duoqin F22 Pro   9990         8.0          0           helio
# 40       apple  Apple iPhone 7s  52990         8.0          0          fusion
# 170       itel     Itel A23 Pro   3999         8.0          0      spreadtrum
# ..         ...              ...    ...         ...        ...             ...
# 712      tecno     Tecno Pova 3   9999         7.4          0           helio
# 411    oukitel      Oukitel WP9  25899         7.2          0           helio
# 410    oukitel     Oukitel WP21  22990         8.2          0           helio
# 409    oukitel     Oukitel WP19  29990         8.4          0           helio
# 58      doogee     Doogee V Max  45999         8.8          1       dimensity
#
# ...

# %%
mobile_df[(mobile_df['5G_or_not']==1)]   # Data for a 5G set
# Out:
#     brand_name                        model   price  avg_rating  5G_or_not  \
# 14       apple         Apple iPhone 13 Mini   64900         7.9          1
# 15       apple          Apple iPhone 13 Pro  119900         8.3          1
# 16       apple    Apple iPhone 13 Pro (1TB)  147900         8.4          1
# 17       apple  Apple iPhone 13 Pro (256GB)  129900         8.3          1
# 28       apple          Apple iPhone 14 Pro  119990         7.5          1
# ..         ...                          ...     ...         ...        ...
# 262      nokia                 Nokia N73 5G   46999         8.0          1
# 646    samsung        Samsung Galaxy M54 5G   34999         8.5          1
# 716      tecno                Tecno Pova 5G   15499         7.8          1
# 624    samsung           Samsung Galaxy F63   21999         8.4          1
# 58      doogee                 Doogee V Max   45999         8.8          1
#
#     processor_brand  num_cores  processor_speed  battery_capacity  \
# ...

# %%
mobile_df[(mobile_df['price']>50000)]     # Data for Mobile above 50000
# Out:
#     brand_name                            model   price  avg_rating  \
# 40       apple                  Apple iPhone 7s   52990         8.0
# 732      vertu            Vertu Signature Touch  650000         6.2
# 14       apple             Apple iPhone 13 Mini   64900         7.9
# 45       apple                 Apple iPhone XR2   71999         6.0
# 15       apple              Apple iPhone 13 Pro  119900         8.3
# ..         ...                              ...     ...         ...
# 48        asus  Asus ROG Phone 6 Batman Edition   72999         8.8
# 50        asus       Asus ROG Phone 6D Ultimate  107990         8.0
# 51        asus                 Asus ROG Phone 7   75990         8.7
# 47        asus                 Asus ROG Phone 6   71999         8.6
# 49        asus          Asus ROG Phone 6 Pro 5G   89999         8.8
#
#      5G_or_not processor_brand  num_cores  processor_speed  battery_capacity  \
# ...

# %%
mobile_df[(mobile_df['num_rear_cameras']==3)]
# Out:
#     brand_name                        model   price  avg_rating  5G_or_not  \
# 15       apple          Apple iPhone 13 Pro  119900         8.3          1
# 16       apple    Apple iPhone 13 Pro (1TB)  147900         8.4          1
# 17       apple  Apple iPhone 13 Pro (256GB)  129900         8.3          1
# 28       apple          Apple iPhone 14 Pro  119990         7.5          1
# 29       apple    Apple iPhone 14 Pro (1TB)  172999         7.7          1
# ..         ...                          ...     ...         ...        ...
# 712      tecno                 Tecno Pova 3    9999         7.4          0
# 411    oukitel                  Oukitel WP9   25899         7.2          0
# 410    oukitel                 Oukitel WP21   22990         8.2          0
# 409    oukitel                 Oukitel WP19   29990         8.4          0
# 58      doogee                 Doogee V Max   45999         8.8          1
#
#     processor_brand  num_cores  processor_speed  battery_capacity  \
# ...

# %%
# BIVARIATE ANALYSIS
mobile_df[(mobile_df['brand_name']=='apple') & (mobile_df['internal_memory']==256)]
# Out:
#    brand_name                            model   price  avg_rating  5G_or_not  \
# 17      apple      Apple iPhone 13 Pro (256GB)  129900         8.3          1
# 30      apple      Apple iPhone 14 Pro (256GB)  129990         7.6          1
# 12      apple          Apple iPhone 13 (256GB)   72999         7.9          1
# 22      apple          Apple iPhone 14 (256GB)   75999         8.2          1
# 33      apple  Apple iPhone 14 Pro Max (256GB)  139990         7.7          1
# 26      apple     Apple iPhone 14 Plus (256GB)   84999         8.3          1
# 38      apple          Apple iPhone 15 Pro Max  142990         7.9          1
# 20      apple  Apple iPhone 13 Pro Max (256GB)  139900         8.4          1
# 5       apple          Apple iPhone 12 (256GB)   67999         7.6          1
# 8       apple     Apple iPhone 12 Mini (256GB)   55999         7.5          1
# 9       apple      Apple iPhone 12 Pro (256GB)  119900         8.0          1
#
# ...

# %%
mobile_df[(mobile_df['model']=='Apple iPhone 14 Pro') & (mobile_df['internal_memory']==128)]
# Out:
#    brand_name                model   price  avg_rating  5G_or_not  \
# 28      apple  Apple iPhone 14 Pro  119990         7.5          1
#
#    processor_brand  num_cores  processor_speed  battery_capacity  \
# 28          bionic        6.0             3.22            3200.0
#
#     fast_charging_available  ...  internal_memory  screen_size  refresh_rate  \
# 28                        1  ...              128          6.1           120
#
#     num_rear_cameras   os  primary_camera_rear primary_camera_front  \
# 28                 3  ios                 48.0                 12.0
#
#     extended_memory_available  resolution_height  resolution_width
# 28                          0               2556              1179
#
# [1 rows x 22 columns]

# %%
mobile_df[(mobile_df['brand_name']=='xiaomi') & (mobile_df['price']>20000)]
# Out:
#     brand_name                                              model   price  \
# 909     xiaomi             Xiaomi Redmi K20 Pro Signature Edition  480000
# 873     xiaomi                                Xiaomi Mi Mix Alpha  199990
# 865     xiaomi                            Xiaomi Mi 11 Lite NE 5G   21890
# 866     xiaomi          Xiaomi Mi 11 Lite NE 5G (8GB RAM + 128GB)   22999
# 957     xiaomi             Xiaomi Redmi Note 12 Discovery Edition   26990
# 958     xiaomi                      Xiaomi Redmi Note 12 Explorer   24999
# 848     xiaomi                                  Xiaomi 12 Lite 5G   29990
# 875     xiaomi                               Xiaomi Mix Fold 2 5G  106990
# 872     xiaomi                                    Xiaomi Mi 12 5G   42990
# 855     xiaomi                                       Xiaomi 13 5G   46990
# 859     xiaomi                                      Xiaomi Civi 2   29999
# 845     xiaomi                          Xiaomi 11i HyperCharge 5G   24820
# ...

# %%
# GROUPBY FUNCTION FOR FILTEING
mobile_df.groupby('brand_name')['model'].value_counts(ascending=True)
# Out:
# brand_name  model
# apple       Apple iPhone 11                              1
#             Apple iPhone 11 (128GB)                      1
#             Apple iPhone 11 Pro Max                      1
#             Apple iPhone 12                              1
#             Apple iPhone 12 (128GB)                      1
#                                                         ..
# xiaomi      Xiaomi Redmi Note 9 Pro                      1
#             Xiaomi Redmi Note 9 Pro (4GB RAM + 128GB)    1
#             Xiaomi Redmi Note 9 Pro Max                  1
# zte         ZTE Axon 30S                                 1
#             ZTE Axon 40 Ultra 5G                         1
# Name: model, Length: 980, dtype: int64

# %%
# GROUPING BY MODELS AND SORTING OUT THE HIGHEST PRICE OF MOBILES
mobile_df.groupby('model')['price'].max().sort_values(ascending=False)
# Out:
# model
# Vertu Signature Touch                     650000
# Xiaomi Redmi K20 Pro Signature Edition    480000
# Huawei Mate 50 RS Porsche Design          239999
# Huawei Mate 30 RS Porsche Design          214990
# Xiaomi Mi Mix Alpha                       199990
#                                            ...
# Jio Phone 3                                 4499
# Itel A23 Pro                                3999
# Lyf Earth 1                                 3990
# Lyf Earth 2                                 3890
# Realme C2s                                  3499
# Name: price, Length: 980, dtype: int64

# %%
# GROUPING BY MODELS AND SORTING THE INTENAL SROTAGE FROM HIGHEST TO LOWEST
mobile_df.groupby('model')['internal_memory'].max().sort_values(ascending=False)
# Out:
# model
# Apple iPhone 14 Pro (1TB)                   1024
# Samsung Galaxy Z Fold 4 (12GB RAM + 1TB)    1024
# Apple iPhone 13 Pro Max (1TB)               1024
# Apple iPhone 14 Pro Max (1TB)               1024
# Apple iPhone 13 Pro (1TB)                   1024
#                                             ...
# Realme A1                                     16
# Realme C2                                     16
# Samsung Galaxy A01 Core                       16
# Nokia C01 Plus                                16
# Itel A23 Pro                                   8
# Name: internal_memory, Length: 980, dtype: int64
