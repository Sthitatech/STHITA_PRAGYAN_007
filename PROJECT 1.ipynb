# %% [markdown]
# CAR DATASET PROJECT

# %%
import pandas as pd

# %%
car_df=pd.read_csv('new_cars_prices.csv')
car_df
# Out:
#      web-scraper-order                                          Car Model  \
# 0         1680210890-1                   Porsche Cayenne A/T / Coupe 2020
# 1         1680210890-2                   Porsche Cayenne A/T / Coupe 2020
# 2         1680210890-3                       Porsche Cayenne A/T / S 2020
# 3         1680210890-4                       Porsche Cayenne A/T / S 2020
# 4         1680210890-5                         Lexus LX 570 Automtic 2020
# ...                ...                                                ...
# 3428   1680210890-3429  Citroën C5 Aircross A/T / FEEL / with out sunr...
# 3429   1680210890-3430               Citroën C5 Aircross A/T / SHINE 2023
# 3430   1680210890-3431               Citroën C5 Aircross A/T / SHINE 2023
# 3431   1680210890-3432               Citroën C5 Aircross A/T / SHINE 2023
# 3432   1680210890-3433               Citroën C5 Aircross A/T / SHINE 2023
#
#            Old Price                  Price Change       New Price  date_range
# ...

# %%
car_df.head()
# Out:
#   web-scraper-order                         Car Model       Old Price  \
# 0      1680210890-1  Porsche Cayenne A/T / Coupe 2020  2,262,876\nEGP
# 1      1680210890-2  Porsche Cayenne A/T / Coupe 2020  2,078,727\nEGP
# 2      1680210890-3      Porsche Cayenne A/T / S 2020  2,388,000\nEGP
# 3      1680210890-4      Porsche Cayenne A/T / S 2020  2,262,876\nEGP
# 4      1680210890-5        Lexus LX 570 Automtic 2020  5,600,000\nEGP
#
#                    Price Change       New Price  date_range
# 0   trending_down\n-82,876\nEGP  2,180,000\nEGP  18/11/2020
# 1    trending_up\n+184,149\nEGP  2,262,876\nEGP  14/10/2019
# 2   trending_down\n-93,000\nEGP  2,295,000\nEGP  18/11/2020
# 3    trending_up\n+125,124\nEGP  2,388,000\nEGP  15/10/2019
# 4  trending_down\n-350,000\nEGP  5,250,000\nEGP  18/05/2020

# %%
car_df.tail()
# Out:
#      web-scraper-order                                          Car Model  \
# 3428   1680210890-3429  Citroën C5 Aircross A/T / FEEL / with out sunr...
# 3429   1680210890-3430               Citroën C5 Aircross A/T / SHINE 2023
# 3430   1680210890-3431               Citroën C5 Aircross A/T / SHINE 2023
# 3431   1680210890-3432               Citroën C5 Aircross A/T / SHINE 2023
# 3432   1680210890-3433               Citroën C5 Aircross A/T / SHINE 2023
#
#            Old Price                Price Change       New Price  date_range
# 3428    779,900\nEGP   trending_up\n+35,000\nEGP    814,900\nEGP  30/11/2022
# 3429  1,149,000\nEGP  trending_up\n+170,000\nEGP  1,319,000\nEGP  27/03/2023
# 3430  1,070,000\nEGP   trending_up\n+79,000\nEGP  1,149,000\nEGP  01/02/2023
# 3431    899,900\nEGP  trending_up\n+170,100\nEGP  1,070,000\nEGP  10/01/2023
# 3432    864,900\nEGP   trending_up\n+35,000\nEGP    899,900\nEGP  30/11/2022

# %%
car_df.shape
# Out:
# (3433, 6)

# %%
car_df.describe()
# Out:
#        web-scraper-order                            Car Model     Old Price  \
# count               3433                                 3433          3433
# unique              3433                                  644          1131
# top         1680210890-1  Chery Tiggo 7 pro A/T / Luxury 2022  445,000\nEGP
# freq                   1                                   10            23
#
#                      Price Change     New Price  date_range
# count                        3433          3433        3433
# unique                        445          1170         268
# top     trending_up\n+10,000\nEGP  445,000\nEGP  15/01/2023
# freq                          293            24          79

# %%
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3433 entries, 0 to 3432
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   web-scraper-order  3433 non-null   object
#  1   Car Model          3433 non-null   object
#  2   Old Price          3433 non-null   object
#  3   Price Change       3433 non-null   object
#  4   New Price          3433 non-null   object
#  5   date_range         3433 non-null   object
# dtypes: object(6)
# memory usage: 161.0+ KB

# %%
car_df.isnull().sum()
# Out:
# web-scraper-order    0
# Car Model            0
# Old Price            0
# Price Change         0
# New Price            0
# date_range           0
# dtype: int64

# %%
car_df['Car Model'].unique()
# Out:
# array(['Porsche Cayenne A/T / Coupe 2020', 'Porsche Cayenne A/T / S 2020',
#        'Lexus LX 570 Automtic 2020', 'Lexus ES 350 Automtic 2020',
#        'Lexus LS 500 Automtic 2020', 'Porsche Macan A/T 2020',
#        'Porsche Macan A/T / S 2020', 'Porsche Boxster M/T / 718 2020',
#        'Toyota Corolla Automatic / SMART / Sun Roof 2022',
#        'Toyota Corolla Automtic / GR 2022',
#        'Toyota Corolla Automatic / Elgance 2022',
#        'Lada Granta manual\u200f / salon 2022',
#        'Lada Granta A/T / E1 2022', 'Lada Granta A/T / E2 2022',
#        'Toyota Fortuner Automtic / ELEGANCE 2022',
#        'Toyota Fortuner A/T / SMART 2022',
#        'Nissan Sunny Manual\u200f / Baseline 2022',
#        'Nissan Sunny Automatic / Baseline 2022',
#        'Nissan Sunny A/T / Super Saloon 2022',
#        'Nissan Sunny A/T / Midline 2022',
#        'Hyundai Tucson A/T / Smart 2022',
#        'Hyundai Tucson A/T / Smart Plus 2022',
#        'Hyundai Tucson A/T / Modern 2022',
# ...

# %%
car_df.columns
# Out:
# Index(['web-scraper-order', 'Car Model', 'Old Price', 'Price Change',
#        'New Price', 'date_range'],
#       dtype='object')

# %%
new_car_df=car_df['Old Price'].apply(lambda x:x.split(',')[0]).astype(int)

# %%
new_car_df
# Out:
# 0         2
# 1         2
# 2         2
# 3         2
# 4         5
#        ...
# 3428    779
# 3429      1
# 3430      1
# 3431    899
# 3432    864
# Name: Old Price, Length: 3433, dtype: int32

# %%
car_df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3428    False
# 3429    False
# 3430    False
# 3431    False
# 3432    False
# Length: 3433, dtype: bool

# %%
car_df['Old Price'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 3428    False
# 3429    False
# 3430     True
# 3431    False
# 3432    False
# Name: Old Price, Length: 3433, dtype: bool

# %%
new_df=car_df['Old Price'].drop_duplicates()

# %%
new_df
# Out:
# 0       2,262,876\nEGP
# 1       2,078,727\nEGP
# 2       2,388,000\nEGP
# 4       5,600,000\nEGP
# 5       5,800,000\nEGP
#              ...
# 3427      814,900\nEGP
# 3428      779,900\nEGP
# 3429    1,149,000\nEGP
# 3431      899,900\nEGP
# 3432      864,900\nEGP
# Name: Old Price, Length: 1131, dtype: object

# %%
car_df['Car Model'].duplicated()
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 3428     True
# 3429    False
# 3430     True
# 3431     True
# 3432     True
# Name: Car Model, Length: 3433, dtype: bool

# %%
car_df['Car Model'].drop_duplicates()
# Out:
# 0                        Porsche Cayenne A/T / Coupe 2020
# 2                            Porsche Cayenne A/T / S 2020
# 4                              Lexus LX 570 Automtic 2020
# 7                              Lexus ES 350 Automtic 2020
# 9                              Lexus LS 500 Automtic 2020
#                               ...
# 3413                          Citroën C4 A/T / Shine 2023
# 3417             Citroën C4 A/T / Shine Red interior 2023
# 3421                  Citroën C5 Aircross A/T / Live 2023
# 3425    Citroën C5 Aircross A/T / FEEL / with out sunr...
# 3429                 Citroën C5 Aircross A/T / SHINE 2023
# Name: Car Model, Length: 644, dtype: object

# %%
car_df.head(12)
# Out:
#    web-scraper-order                         Car Model       Old Price  \
# 0       1680210890-1  Porsche Cayenne A/T / Coupe 2020  2,262,876\nEGP
# 1       1680210890-2  Porsche Cayenne A/T / Coupe 2020  2,078,727\nEGP
# 2       1680210890-3      Porsche Cayenne A/T / S 2020  2,388,000\nEGP
# 3       1680210890-4      Porsche Cayenne A/T / S 2020  2,262,876\nEGP
# 4       1680210890-5        Lexus LX 570 Automtic 2020  5,600,000\nEGP
# 5       1680210890-6        Lexus LX 570 Automtic 2020  5,800,000\nEGP
# 6       1680210890-7        Lexus LX 570 Automtic 2020  5,800,000\nEGP
# 7       1680210890-8        Lexus ES 350 Automtic 2020  2,830,000\nEGP
# 8       1680210890-9        Lexus ES 350 Automtic 2020  2,650,000\nEGP
# 9      1680210890-10        Lexus LS 500 Automtic 2020  5,400,000\nEGP
# 10     1680210890-11        Lexus LS 500 Automtic 2020  6,150,000\nEGP
# 11     1680210890-12        Lexus LS 500 Automtic 2020  6,750,000\nEGP
#
# ...

# %%
car_df[(car_df['Car Model']=='Lexus LS 500 Automtic 2020') & (car_df['Old Price']=='6,750,000\nEGP')]
# Out:
#    web-scraper-order                   Car Model       Old Price  \
# 11     1680210890-12  Lexus LS 500 Automtic 2020  6,750,000\nEGP
#
#                     Price Change       New Price  date_range
# 11  trending_down\n-500,000\nEGP  6,250,000\nEGP  18/05/2020
